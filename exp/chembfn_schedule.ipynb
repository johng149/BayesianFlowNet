# %%
import torch

# %%
K = 37
beta_1_value = 20.4054 / K

# %%
t = torch.tensor([0.5])
beta_1 = torch.tensor([beta_1_value])

# %%
(-4 / K) * torch.log(1 - t + t * torch.exp(-K * beta_1 / 4))
# Out:
# tensor([0.0743])

# %%
t = torch.tensor([0.5, 0.5])
beta_1 = torch.tensor([beta_1_value, beta_1_value])

# %%
(-4 / K) * torch.log(1 - t + t * torch.exp(-K * beta_1 / 4))
# Out:
# tensor([0.0743, 0.0743])
